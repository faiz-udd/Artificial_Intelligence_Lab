# %%
from pandas import read_csv
import pandas as pd

path = r"E:\Univeristy Material\6th Semester\Computer Science Courses\Artificial Intelligence\Labs\lab2.ipynb"
data=pd.read_csv(path, sep='\t')
print(data.shape)
print(data.dtypes)
data
# Out:
# (175, 1)
# {    object
# dtype: object
#                              {
# 0                   "cells": [
# 1                            {
# 2         "cell_type": "code",
# 3       "execution_count": 15,
# 4            "id": "6ebab3d6",
# ..                         ...
# 170                          }
# 171                         },
# 172             "nbformat": 4,
# 173        "nbformat_minor": 5
# 174                          }
#
# [175 rows x 1 columns]

# %%
path1 = r"E:\Univeristy Material\6th Semester\Computer Science Courses\Artificial Intelligence\Labs\pima-indians-diabetes1.csv"
headernames = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(path1, names=headernames)

data[40:50]
# Out:
#     preg  plas  pres  skin  test  mass   pedi  age  class
# 40     3   180    64    25    70  34.0  0.271   26      0
# 41     7   133    84     0     0  40.2  0.696   37      0
# 42     7   106    92    18     0  22.7  0.235   48      0
# 43     9   171   110    24   240  45.4  0.721   54      1
# 44     7   159    64     0     0  27.4  0.294   40      0
# 45     0   180    66    39     0  42.0  1.893   25      1
# 46     1   146    56     0     0  29.7  0.564   29      0
# 47     2    71    70    27     0  28.0  0.586   22      0
# 48     7   103    66    32     0  39.1  0.344   31      1
# 49     7   105     0     0     0   0.0  0.305   24      0

# %%
from pandas import set_option
set_option('precision', 3)

data.describe()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 from pandas import set_option
# ----> 2 set_option('precision', 2)
#       4 data.describe()
#
# File c:\Python312\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File c:\Python312\Lib\site-packages\pandas\_config\config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# File c:\Python312\Lib\site-packages\pandas\_config\config.py:134, in _get_single_key(pat, silent)
# ...

# %%
count_class = data['class'].value_counts()
print(count_class)

# %%
# correlation between attributes

correlations = data.corr(method='pearson')
print(correlations)

# %%
# skew
skew = data.skew()
print(skew)

# %%
# histogram
from matplotlib import pyplot

data.hist()
pyplot.tight_layout()
pyplot.show()

# %%
# density 
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False )
pyplot.tight_layout()
pyplot.show()

# %%
# box and whiskers 
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False,sharey=False)
pyplot.tight_layout()

pyplot.show()
